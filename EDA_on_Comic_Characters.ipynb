# %%
#EDA ON SUPERHEROES DATSET

# %%
#loading required libraries
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
marvel = pd.read_csv('marvel_demo_stats_powers.csv')
print('Data is ready fo EDA')
# Out:
# Data is ready fo EDA

# %%
marvel.head()
# Out:
#             Name Alignment_x  Intelligence_x  Strength  Speed  Durability_x  \
# 0         A-Bomb        good            38.0     100.0   17.0          80.0
# 1    Abomination         bad            63.0      80.0   53.0          90.0
# 2        Abraxas         bad            88.0     100.0   83.0          99.0
# 3  Absorbing Man         bad             NaN       NaN    NaN           NaN
# 4       Agent 13        good             NaN       NaN    NaN           NaN
#
#    Power  Combat  Total
# 0   17.0    64.0  316.0
# 1   55.0    95.0  436.0
# 2  100.0    56.0  526.0
# 3    NaN     NaN    NaN
# 4    NaN     NaN    NaN

# %%
marvel.shape
# Out:
# (382, 9)

# %%
marvel['Alignment_x'].value_counts()
# Out:
# Alignment_x
# good       254
# bad        114
# neutral     11
# -            3
# Name: count, dtype: int64

# %%
marvel[marvel['Alignment_x']=='good']
# Out:
#                 Name Alignment_x  Intelligence_x  Strength  Speed  \
# 0             A-Bomb        good            38.0     100.0   17.0
# 4           Agent 13        good             NaN       NaN    NaN
# 5          Agent Bob        good            10.0       8.0   13.0
# 6         Agent Zero        good            75.0      28.0   38.0
# 10             Angel        good            63.0      13.0   46.0
# ..               ...         ...             ...       ...    ...
# 376             X-23        good            75.0      24.0   35.0
# 377            X-Man        good            88.0      53.0   53.0
# 379     Yellowjacket        good            88.0      10.0   12.0
# 380  Yellowjacket II        good            50.0      10.0   35.0
# 381             Ymir        good            50.0     100.0   27.0
#
#      Durability_x  Power  Combat  Total
# 0            80.0   17.0    64.0  316.0
# 4             NaN    NaN     NaN    NaN
# 5             5.0    5.0    20.0   61.0
# ...

# %%
good_characters = marvel[marvel['Alignment_x']=='good']
good_characters
# Out:
#                 Name Alignment_x  Intelligence_x  Strength  Speed  \
# 0             A-Bomb        good            38.0     100.0   17.0
# 4           Agent 13        good             NaN       NaN    NaN
# 5          Agent Bob        good            10.0       8.0   13.0
# 6         Agent Zero        good            75.0      28.0   38.0
# 10             Angel        good            63.0      13.0   46.0
# ..               ...         ...             ...       ...    ...
# 376             X-23        good            75.0      24.0   35.0
# 377            X-Man        good            88.0      53.0   53.0
# 379     Yellowjacket        good            88.0      10.0   12.0
# 380  Yellowjacket II        good            50.0      10.0   35.0
# 381             Ymir        good            50.0     100.0   27.0
#
#      Durability_x  Power  Combat  Total
# 0            80.0   17.0    64.0  316.0
# 4             NaN    NaN     NaN    NaN
# 5             5.0    5.0    20.0   61.0
# ...

# %%
good_characters.sort_values(by=['Speed'],ascending=False)
# Out:
#                Name Alignment_x  Intelligence_x  Strength  Speed  \
# 183  Jack of Hearts        good            63.0      55.0  100.0
# 43       Black Bolt        good            75.0      67.0  100.0
# 321        Stardust        good            88.0      85.0  100.0
# 252         Nova II        good            38.0      60.0  100.0
# 270     Quicksilver        good            63.0      28.0  100.0
# ..              ...         ...             ...       ...    ...
# 262         Polaris        good             NaN       NaN    NaN
# 300            Silk        good             NaN       NaN    NaN
# 311     Spider-Gwen        good             NaN       NaN    NaN
# 320       Star-Lord        good             NaN       NaN    NaN
# 342          Triton        good             NaN       NaN    NaN
#
#      Durability_x  Power  Combat  Total
# 183          30.0   70.0    30.0  348.0
# 43           84.0  100.0    56.0  482.0
# 321         110.0  100.0    85.0  568.0
# ...

# %%
good_characters.sort_values(by=['Speed'],ascending=False).head()
# Out:
#                Name Alignment_x  Intelligence_x  Strength  Speed  \
# 183  Jack of Hearts        good            63.0      55.0  100.0
# 43       Black Bolt        good            75.0      67.0  100.0
# 321        Stardust        good            88.0      85.0  100.0
# 252         Nova II        good            38.0      60.0  100.0
# 270     Quicksilver        good            63.0      28.0  100.0
#
#      Durability_x  Power  Combat  Total
# 183          30.0   70.0    30.0  348.0
# 43           84.0  100.0    56.0  482.0
# 321         110.0  100.0    85.0  568.0
# 252         100.0  100.0    25.0  423.0
# 270          60.0   57.0    56.0  364.0

# %%
good_characters.sort_values(by=['Power'],ascending=False)
# Out:
#             Name Alignment_x  Intelligence_x  Strength  Speed  Durability_x  \
# 252      Nova II        good            38.0      60.0  100.0         100.0
# 177       Iceman        good            63.0      32.0   53.0         100.0
# 43    Black Bolt        good            75.0      67.0  100.0          84.0
# 260      Phoenix        good           100.0      80.0   67.0         100.0
# 35      Beyonder        good            88.0     100.0   23.0         100.0
# ..           ...         ...             ...       ...    ...           ...
# 262      Polaris        good             NaN       NaN    NaN           NaN
# 300         Silk        good             NaN       NaN    NaN           NaN
# 311  Spider-Gwen        good             NaN       NaN    NaN           NaN
# 320    Star-Lord        good             NaN       NaN    NaN           NaN
# 342       Triton        good             NaN       NaN    NaN           NaN
#
#      Power  Combat  Total
# 252  100.0    25.0  423.0
# ...

# %%
good_characters.sort_values(by=['Power'],ascending=False).head()
# Out:
#            Name Alignment_x  Intelligence_x  Strength  Speed  Durability_x  \
# 252     Nova II        good            38.0      60.0  100.0         100.0
# 177      Iceman        good            63.0      32.0   53.0         100.0
# 43   Black Bolt        good            75.0      67.0  100.0          84.0
# 260     Phoenix        good           100.0      80.0   67.0         100.0
# 35     Beyonder        good            88.0     100.0   23.0         100.0
#
#      Power  Combat  Total
# 252  100.0    25.0  423.0
# 177  100.0    64.0  412.0
# 43   100.0    56.0  482.0
# 260  100.0    70.0  517.0
# 35   100.0    56.0  467.0

# %%
good_characters_max_power = good_characters[good_characters['Power']==100]
good_characters_max_power
# Out:
#                Name Alignment_x  Intelligence_x  Strength  Speed  \
# 34    Beta Ray Bill        good            63.0      80.0   35.0
# 35         Beyonder        good            88.0     100.0   23.0
# 43       Black Bolt        good            75.0      67.0  100.0
# 73            Cable        good            88.0      48.0   23.0
# 115  Doctor Strange        good           100.0      10.0   12.0
# 177          Iceman        good            63.0      32.0   53.0
# 181        Iron Man        good           100.0      85.0   58.0
# 184       Jean Grey        good           100.0      80.0   67.0
# 220     Marvel Girl        good            63.0      85.0   47.0
# 251            Nova        good           100.0      85.0   67.0
# 252         Nova II        good            38.0      60.0  100.0
# 260         Phoenix        good           100.0      80.0   67.0
# 291     Shadow King        good            75.0      12.0   27.0
# ...

# %%
good_characters_max_power.shape
# Out:
# (19, 9)

# %%
good_characters_max_power=good_characters.sort_values(by=['Total'],ascending=False)
good_characters_max_power
# Out:
#             Name Alignment_x  Intelligence_x  Strength  Speed  Durability_x  \
# 321     Stardust        good            88.0      85.0  100.0         110.0
# 330         Thor        good            69.0     100.0   92.0         100.0
# 251         Nova        good           100.0      85.0   67.0         101.0
# 184    Jean Grey        good           100.0      80.0   67.0         100.0
# 260      Phoenix        good           100.0      80.0   67.0         100.0
# ..           ...         ...             ...       ...    ...           ...
# 262      Polaris        good             NaN       NaN    NaN           NaN
# 300         Silk        good             NaN       NaN    NaN           NaN
# 311  Spider-Gwen        good             NaN       NaN    NaN           NaN
# 320    Star-Lord        good             NaN       NaN    NaN           NaN
# 342       Triton        good             NaN       NaN    NaN           NaN
#
#      Power  Combat  Total
# 321  100.0    85.0  568.0
# ...

# %%
good_characters_max_power.head()
# Out:
#           Name Alignment_x  Intelligence_x  Strength  Speed  Durability_x  \
# 321   Stardust        good            88.0      85.0  100.0         110.0
# 330       Thor        good            69.0     100.0   92.0         100.0
# 251       Nova        good           100.0      85.0   67.0         101.0
# 184  Jean Grey        good           100.0      80.0   67.0         100.0
# 260    Phoenix        good           100.0      80.0   67.0         100.0
#
#      Power  Combat  Total
# 321  100.0    85.0  568.0
# 330  100.0    85.0  546.0
# 251  100.0    85.0  538.0
# 184  100.0    70.0  517.0
# 260  100.0    70.0  517.0

# %%
good_characters_max_power.tail()
# Out:
#             Name Alignment_x  Intelligence_x  Strength  Speed  Durability_x  \
# 262      Polaris        good             NaN       NaN    NaN           NaN
# 300         Silk        good             NaN       NaN    NaN           NaN
# 311  Spider-Gwen        good             NaN       NaN    NaN           NaN
# 320    Star-Lord        good             NaN       NaN    NaN           NaN
# 342       Triton        good             NaN       NaN    NaN           NaN
#
#      Power  Combat  Total
# 262    NaN     NaN    NaN
# 300    NaN     NaN    NaN
# 311    NaN     NaN    NaN
# 320    NaN     NaN    NaN
# 342    NaN     NaN    NaN

# %%
plt.figure(figsize=(8,5))
plt.bar(list(good_characters_max_power['Name'])[0:5],list(good_characters_max_power['Total'])[0:5],color=('orange','pink','purple','salmon','teal'))
plt.show()

# %%
bad_characters = marvel[marvel['Alignment_x']=='bad']
bad_characters
# Out:
#               Name Alignment_x  Intelligence_x  Strength  Speed  Durability_x  \
# 1      Abomination         bad            63.0      80.0   53.0          90.0
# 2          Abraxas         bad            88.0     100.0   83.0          99.0
# 3    Absorbing Man         bad             NaN       NaN    NaN           NaN
# 7       Air-Walker         bad            50.0      85.0  100.0          85.0
# 8             Ajax         bad             NaN       NaN    NaN           NaN
# ..             ...         ...             ...       ...    ...           ...
# 351      Venom III         bad            63.0      73.0   35.0          90.0
# 359        Vulture         bad            63.0      22.0   47.0          56.0
# 360         Walrus         bad            50.0      28.0    8.0          50.0
# 367      Weapon XI         bad             1.0       1.0    1.0           1.0
# 378    Yellow Claw         bad             1.0       1.0    1.0           1.0
#
#      Power  Combat  Total
# ...

# %%
bad_characters.sort_values(by=['Speed'],ascending=False)
# Out:
#                Name Alignment_x  Intelligence_x  Strength  Speed  \
# 7        Air-Walker         bad            50.0      85.0  100.0
# 129   Fallen One II         bad            88.0      85.0   83.0
# 120             Ego         bad            88.0      80.0   83.0
# 118        Dormammu         bad            88.0      95.0   83.0
# 2           Abraxas         bad            88.0     100.0   83.0
# ..              ...         ...             ...       ...    ...
# 268      Purple Man         bad             NaN       NaN    NaN
# 289  Sebastian Shaw         bad             NaN       NaN    NaN
# 305      Snake-Eyes         bad             NaN       NaN    NaN
# 324           Swarm         bad             NaN       NaN    NaN
# 326      Taskmaster         bad             NaN       NaN    NaN
#
#      Durability_x  Power  Combat  Total
# 7            85.0  100.0    40.0  460.0
# 129         100.0  100.0    56.0  512.0
# 120          99.0   71.0    28.0  449.0
# ...

# %%
bad_characters.sort_values(by=['Speed'],ascending=False).head()
# Out:
#               Name Alignment_x  Intelligence_x  Strength  Speed  Durability_x  \
# 7       Air-Walker         bad            50.0      85.0  100.0          85.0
# 129  Fallen One II         bad            88.0      85.0   83.0         100.0
# 120            Ego         bad            88.0      80.0   83.0          99.0
# 118       Dormammu         bad            88.0      95.0   83.0         100.0
# 2          Abraxas         bad            88.0     100.0   83.0          99.0
#
#      Power  Combat  Total
# 7    100.0    40.0  460.0
# 129  100.0    56.0  512.0
# 120   71.0    28.0  449.0
# 118  100.0    80.0  546.0
# 2    100.0    56.0  526.0

# %%
bad_characters.sort_values(by=['Intelligence_x'],ascending=False).head()
# Out:
#             Name Alignment_x  Intelligence_x  Strength  Speed  Durability_x  \
# 218     Mandarin         bad           100.0      28.0   23.0          28.0
# 17    Apocalypse         bad           100.0     100.0   33.0         100.0
# 194         Kang         bad           100.0      48.0   58.0          70.0
# 112  Doctor Doom         bad           100.0      32.0   20.0         100.0
# 339     Tinkerer         bad           100.0      10.0   23.0          14.0
#
#      Power  Combat  Total
# 218   99.0    95.0  373.0
# 17   100.0    60.0  493.0
# 194   71.0    70.0  417.0
# 112   93.0    84.0  429.0
# 339   10.0    14.0  171.0

# %%
bad_characters.sort_values(by=['Power'],ascending=False).head()
# Out:
#          Name Alignment_x  Intelligence_x  Strength  Speed  Durability_x  \
# 118  Dormammu         bad            88.0      95.0   83.0         100.0
# 328    Thanos         bad            88.0     100.0   17.0         100.0
# 344    Ultron         bad            88.0      83.0   42.0         100.0
# 224  Mephisto         bad            88.0      85.0   35.0          95.0
# 126    Exodus         bad            63.0      81.0   28.0          28.0
#
#      Power  Combat  Total
# 118  100.0    80.0  546.0
# 328  100.0    80.0  485.0
# 344  100.0    64.0  477.0
# 224  100.0    42.0  445.0
# 126  100.0    70.0  370.0

# %%
plt.figure(figsize=(8,5))
plt.hist(bad_characters['Speed'],color='olive')
plt.title('Distribution of Speed')
plt.xlabel('Speed')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(good_characters['Combat'],color='violet',ec='purple')
plt.title('Distribution of Combat')
plt.xlabel('Speed')
plt.tight_layout()
plt.show()
