# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns
import plotly
import plotly.express as px
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, plot, iplot
from plotly import tools
from warnings import filterwarnings
filterwarnings('ignore')

# %%
ipl = pd.read_csv('ipl_dataset.csv')
print('Data is ready for exploration')
# Out:
# Data is ready for exploration

# %%
ipl.head()
# Out:
#    id  season       city      date                        team1  \
# 0   1    2017  Hyderabad  5/4/2017          Sunrisers Hyderabad
# 1   2    2017       Pune  6/4/2017               Mumbai Indians
# 2   3    2017     Rajkot  7/4/2017                Gujarat Lions
# 3   4    2017     Indore  8/4/2017       Rising Pune Supergiant
# 4   5    2017  Bangalore  8/4/2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0          Sunrisers Hyderabad           35
# ...

# %%
ipl.tail()
# Out:
#       id  season       city      date                team1  \
# 631  632    2016     Raipur  22/05/16     Delhi Daredevils
# 632  633    2016  Bangalore  24/05/16        Gujarat Lions
# 633  634    2016      Delhi  25/05/16  Sunrisers Hyderabad
# 634  635    2016      Delhi  27/05/16        Gujarat Lions
# 635  636    2016  Bangalore  29/05/16  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 631  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 632  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 633        Kolkata Knight Riders        Kolkata Knight Riders         field
# 634          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 635  Royal Challengers Bangalore          Sunrisers Hyderabad           bat
#
#      result  dl_applied                       winner  win_by_runs  \
# 631  normal           0  Royal Challengers Bangalore            0
# ...

# %%
ipl.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
ipl.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               3
# win_by_runs          0
# win_by_wickets       0
# player_of_match      3
# venue                0
# umpire1              1
# umpire2              1
# umpire3            636
# dtype: int64

# %%
ipl.shape
# Out:
# (636, 18)

# %%
print('Total Matches Played:',ipl.shape[0])
print(' \n Venues Played At:',ipl['city'].unique())     
print(' \n Teams :',ipl['team1'].unique())
# Out:
# Total Matches Played: 636
#
#  Venues Played At: ['Hyderabad' 'Pune' 'Rajkot' 'Indore' 'Bangalore' 'Mumbai' 'Kolkata'
#  'Delhi' 'Chandigarh' 'Kanpur' 'Jaipur' 'Chennai' 'Cape Town'
#  'Port Elizabeth' 'Durban' 'Centurion' 'East London' 'Johannesburg'
#  'Kimberley' 'Bloemfontein' 'Ahmedabad' 'Cuttack' 'Nagpur' 'Dharamsala'
#  'Kochi' 'Visakhapatnam' 'Raipur' 'Ranchi' 'Abu Dhabi' 'Sharjah' nan]
#
#  Teams : ['Sunrisers Hyderabad' 'Mumbai Indians' 'Gujarat Lions'
#  'Rising Pune Supergiant' 'Royal Challengers Bangalore'
#  'Kolkata Knight Riders' 'Delhi Daredevils' 'Kings XI Punjab'
#  'Chennai Super Kings' 'Rajasthan Royals' 'Deccan Chargers'
#  'Kochi Tuskers Kerala' 'Pune Warriors' 'Rising Pune Supergiants']

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %%
#ipl['team1'] = ipl['team1'].astype(int)

# %%
ipl['team1'] = pd.to_numeric(ipl['team1'], downcast='integer', errors='coerce')
#print(ipl)
ipl['team1'].dtype
ipl['team1']
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 631   NaN
# 632   NaN
# 633   NaN
# 634   NaN
# 635   NaN
# Name: team1, Length: 636, dtype: float64

# %%
ipl.head()
# Out:
#    id  season       city      date  team1                        team2  \
# 0   1    2017  Hyderabad  5/4/2017    NaN  Royal Challengers Bangalore
# 1   2    2017       Pune  6/4/2017    NaN       Rising Pune Supergiant
# 2   3    2017     Rajkot  7/4/2017    NaN        Kolkata Knight Riders
# 3   4    2017     Indore  8/4/2017    NaN              Kings XI Punjab
# 4   5    2017  Bangalore  8/4/2017    NaN             Delhi Daredevils
#
#                    toss_winner toss_decision  result  dl_applied  \
# 0  Royal Challengers Bangalore         field  normal           0
# 1       Rising Pune Supergiant         field  normal           0
# 2        Kolkata Knight Riders         field  normal           0
# 3              Kings XI Punjab         field  normal           0
# 4  Royal Challengers Bangalore           bat  normal           0
#
#                         winner  win_by_runs  win_by_wickets player_of_match  \
# ...

# %%
ipl = pd.read_csv('ipl_dataset.csv')
ipl
# Out:
#       id  season       city      date                        team1  \
# 0      1    2017  Hyderabad  5/4/2017          Sunrisers Hyderabad
# 1      2    2017       Pune  6/4/2017               Mumbai Indians
# 2      3    2017     Rajkot  7/4/2017                Gujarat Lions
# 3      4    2017     Indore  8/4/2017       Rising Pune Supergiant
# 4      5    2017  Bangalore  8/4/2017  Royal Challengers Bangalore
# ..   ...     ...        ...       ...                          ...
# 631  632    2016     Raipur  22/05/16             Delhi Daredevils
# 632  633    2016  Bangalore  24/05/16                Gujarat Lions
# 633  634    2016      Delhi  25/05/16          Sunrisers Hyderabad
# 634  635    2016      Delhi  27/05/16                Gujarat Lions
# 635  636    2016  Bangalore  29/05/16          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
#ipl['team1'] = int(ipl['team1'].strip())

# %%
##ipl['team1'] = ipl['team1'].apply(lambda x: int(x))
#print(ipl)
#df['team1'].dtype

# %%
print('Total Matches Played:',ipl.shape[0])
print(' \n Venues Played At:',ipl['city'].unique())     
print(' \n Teams :',ipl['team1'].unique())
# Out:
# Total Matches Played: 636
#
#  Venues Played At: ['Hyderabad' 'Pune' 'Rajkot' 'Indore' 'Bangalore' 'Mumbai' 'Kolkata'
#  'Delhi' 'Chandigarh' 'Kanpur' 'Jaipur' 'Chennai' 'Cape Town'
#  'Port Elizabeth' 'Durban' 'Centurion' 'East London' 'Johannesburg'
#  'Kimberley' 'Bloemfontein' 'Ahmedabad' 'Cuttack' 'Nagpur' 'Dharamsala'
#  'Kochi' 'Visakhapatnam' 'Raipur' 'Ranchi' 'Abu Dhabi' 'Sharjah' nan]
#
#  Teams : ['Sunrisers Hyderabad' 'Mumbai Indians' 'Gujarat Lions'
#  'Rising Pune Supergiant' 'Royal Challengers Bangalore'
#  'Kolkata Knight Riders' 'Delhi Daredevils' 'Kings XI Punjab'
#  'Chennai Super Kings' 'Rajasthan Royals' 'Deccan Chargers'
#  'Kochi Tuskers Kerala' 'Pune Warriors' 'Rising Pune Supergiants']

# %%
ipl
# Out:
#       id  season       city      date                        team1  \
# 0      1    2017  Hyderabad  5/4/2017          Sunrisers Hyderabad
# 1      2    2017       Pune  6/4/2017               Mumbai Indians
# 2      3    2017     Rajkot  7/4/2017                Gujarat Lions
# 3      4    2017     Indore  8/4/2017       Rising Pune Supergiant
# 4      5    2017  Bangalore  8/4/2017  Royal Challengers Bangalore
# ..   ...     ...        ...       ...                          ...
# 631  632    2016     Raipur  22/05/16             Delhi Daredevils
# 632  633    2016  Bangalore  24/05/16                Gujarat Lions
# 633  634    2016      Delhi  25/05/16          Sunrisers Hyderabad
# 634  635    2016      Delhi  27/05/16                Gujarat Lions
# 635  636    2016  Bangalore  29/05/16          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
ipl['player_of_match'].value_counts()
# Out:
# player_of_match
# CH Gayle          18
# YK Pathan         16
# DA Warner         15
# AB de Villiers    15
# RG Sharma         14
#                   ..
# AD Mathews         1
# LR Shukla          1
# R Bhatia           1
# A Singh            1
# BCJ Cutting        1
# Name: count, Length: 201, dtype: int64

# %%
ipl['player_of_match'].value_counts()[0:10]
# Out:
# player_of_match
# CH Gayle          18
# YK Pathan         16
# DA Warner         15
# AB de Villiers    15
# RG Sharma         14
# SK Raina          14
# MS Dhoni          13
# G Gambhir         13
# AM Rahane         12
# MEK Hussey        12
# Name: count, dtype: int64

# %%
ipl['player_of_match'].value_counts()[0:5]
# Out:
# player_of_match
# CH Gayle          18
# YK Pathan         16
# DA Warner         15
# AB de Villiers    15
# RG Sharma         14
# Name: count, dtype: int64

# %%
ipl['player_of_match'].value_counts()[0:5].keys()
# Out:
# Index(['CH Gayle', 'YK Pathan', 'DA Warner', 'AB de Villiers', 'RG Sharma'], dtype='object', name='player_of_match')

# %%
plt.figure(figsize=(8,5))
plt.barh(ipl['player_of_match'].value_counts()[0:5].keys(),ipl['player_of_match'].value_counts()[0:5],color='g')
plt.show()

# %%
cities = ipl['city'].unique()
cities
# Out:
# array(['Hyderabad', 'Pune', 'Rajkot', 'Indore', 'Bangalore', 'Mumbai',
#        'Kolkata', 'Delhi', 'Chandigarh', 'Kanpur', 'Jaipur', 'Chennai',
#        'Cape Town', 'Port Elizabeth', 'Durban', 'Centurion',
#        'East London', 'Johannesburg', 'Kimberley', 'Bloemfontein',
#        'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala', 'Kochi',
#        'Visakhapatnam', 'Raipur', 'Ranchi', 'Abu Dhabi', 'Sharjah', nan],
#       dtype=object)

# %%
ipl['win_by_runs'].value_counts()
# Out:
# win_by_runs
# 0      349
# 23       9
# 10       9
# 9        9
# 7        9
#       ...
# 67       1
# 57       1
# 76       1
# 111      1
# 80       1
# Name: count, Length: 86, dtype: int64

# %%
ipl['result'].value_counts()
# Out:
# result
# normal       626
# tie            7
# no result      3
# Name: count, dtype: int64

# %%
ipl['result'].unique()
# Out:
# array(['normal', 'tie', 'no result'], dtype=object)

# %%
ipl['toss_winner'].value_counts()
# Out:
# toss_winner
# Mumbai Indians                 85
# Kolkata Knight Riders          78
# Delhi Daredevils               72
# Royal Challengers Bangalore    70
# Kings XI Punjab                68
# Chennai Super Kings            66
# Rajasthan Royals               63
# Deccan Chargers                43
# Sunrisers Hyderabad            35
# Pune Warriors                  20
# Gujarat Lions                  15
# Kochi Tuskers Kerala            8
# Rising Pune Supergiants         7
# Rising Pune Supergiant          6
# Name: count, dtype: int64

# %%
batting_first_win = ipl[ipl['win_by_runs'] != 0]
batting_first_win.head()
# Out:
#     id  season       city       date                        team1  \
# 0    1    2017  Hyderabad   5/4/2017          Sunrisers Hyderabad
# 4    5    2017  Bangalore   8/4/2017  Royal Challengers Bangalore
# 8    9    2017       Pune  11/4/2017             Delhi Daredevils
# 13  14    2017    Kolkata   15/04/17        Kolkata Knight Riders
# 14  15    2017      Delhi   15/04/17             Delhi Daredevils
#
#                           team2                  toss_winner toss_decision  \
# 0   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 4              Delhi Daredevils  Royal Challengers Bangalore           bat
# 8        Rising Pune Supergiant       Rising Pune Supergiant         field
# 13          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 14              Kings XI Punjab             Delhi Daredevils           bat
#
#     result  dl_applied                       winner  win_by_runs  \
# ...

# %%
ipl['win_by_runs']
# Out:
# 0      35
# 1       0
# 2       0
# 3       0
# 4      15
#        ..
# 631     0
# 632     0
# 633    22
# 634     0
# 635     8
# Name: win_by_runs, Length: 636, dtype: int64

# %%
plt.figure(figsize=(5,5))
plt.hist(batting_first_win['win_by_runs'],color='m')
plt.title("Distribution of Runs")
plt.xlabel("Runs")
plt.ylabel("Matches")
plt.show()

# %%
batting_first_win['winner'].value_counts()
# Out:
# winner
# Mumbai Indians                 47
# Chennai Super Kings            46
# Kings XI Punjab                32
# Kolkata Knight Riders          31
# Royal Challengers Bangalore    30
# Sunrisers Hyderabad            23
# Rajasthan Royals               23
# Delhi Daredevils               21
# Deccan Chargers                18
# Pune Warriors                   6
# Rising Pune Supergiant          5
# Kochi Tuskers Kerala            2
# Rising Pune Supergiants         2
# Gujarat Lions                   1
# Name: count, dtype: int64

# %%
batting_first_win['winner'].value_counts().keys()
# Out:
# Index(['Mumbai Indians', 'Chennai Super Kings', 'Kings XI Punjab',
#        'Kolkata Knight Riders', 'Royal Challengers Bangalore',
#        'Sunrisers Hyderabad', 'Rajasthan Royals', 'Delhi Daredevils',
#        'Deccan Chargers', 'Pune Warriors', 'Rising Pune Supergiant',
#        'Kochi Tuskers Kerala', 'Rising Pune Supergiants', 'Gujarat Lions'],
#       dtype='object', name='winner')

# %%
plt.figure(figsize=(8,5))
plt.bar(list(batting_first_win['winner'].value_counts()[0:3].keys()),batting_first_win['winner'].value_counts()[0:3],color=['Blue','Yellow','Red'])
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.barh(batting_first_win['winner'].value_counts().keys(),batting_first_win['winner'].value_counts(),color=['Red'])
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.pie(list(batting_first_win['winner'].value_counts()),labels = list(batting_first_win['winner'].value_counts().keys()),autopct = '%0.1f%%',pctdistance=0.9)
plt.tight_layout()
plt.show()

# %%
batting_second_win = ipl[ipl['win_by_wickets'] != 0]
batting_second_win.head()
# Out:
#    id  season       city      date                   team1  \
# 1   2    2017       Pune  6/4/2017          Mumbai Indians
# 2   3    2017     Rajkot  7/4/2017           Gujarat Lions
# 3   4    2017     Indore  8/4/2017  Rising Pune Supergiant
# 5   6    2017  Hyderabad  9/4/2017           Gujarat Lions
# 6   7    2017     Mumbai  9/4/2017   Kolkata Knight Riders
#
#                     team2             toss_winner toss_decision  result  \
# 1  Rising Pune Supergiant  Rising Pune Supergiant         field  normal
# 2   Kolkata Knight Riders   Kolkata Knight Riders         field  normal
# 3         Kings XI Punjab         Kings XI Punjab         field  normal
# 5     Sunrisers Hyderabad     Sunrisers Hyderabad         field  normal
# 6          Mumbai Indians          Mumbai Indians         field  normal
#
#    dl_applied                  winner  win_by_runs  win_by_wickets  \
# 1           0  Rising Pune Supergiant            0               7
# ...

# %%
plt.figure(figsize=(5,5))
plt.hist(batting_second_win['win_by_wickets'],bins=20, color='skyblue',histtype='stepfilled')
plt.title("Distribution of wickets")
plt.xlabel("wickets")
plt.ylabel("Nos of Matches")
plt.tight_layout()
plt.show()

# %%
batting_second_win['winner'].value_counts()
# Out:
# winner
# Kolkata Knight Riders          46
# Mumbai Indians                 44
# Royal Challengers Bangalore    42
# Delhi Daredevils               41
# Rajasthan Royals               38
# Kings XI Punjab                36
# Chennai Super Kings            33
# Sunrisers Hyderabad            18
# Gujarat Lions                  12
# Deccan Chargers                11
# Pune Warriors                   6
# Rising Pune Supergiant          5
# Kochi Tuskers Kerala            4
# Rising Pune Supergiants         3
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,10))
plt.pie(list(batting_second_win['winner'].value_counts()),labels = list(batting_second_win['winner'].value_counts().keys()),autopct = '%0.1f%%',pctdistance=0.9)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.barh(batting_second_win['winner'].value_counts().keys(),batting_second_win['winner'].value_counts(),color=['pink'])
plt.show()

# %%
plt.figure(figsize=(5,5))
plt.bar(list(batting_second_win['winner'].value_counts()[0:3].keys()),list(batting_second_win['winner'].value_counts()[0:3]),color=['purple','blue','Red'])
plt.xticks(rotation ='vertical')
plt.show()

# %%
ipl['season'].value_counts()
# Out:
# season
# 2013    76
# 2012    74
# 2011    73
# 2010    60
# 2014    60
# 2016    60
# 2017    59
# 2015    59
# 2008    58
# 2009    57
# Name: count, dtype: int64

# %%
ipl['city'].value_counts()
# Out:
# city
# Mumbai            85
# Bangalore         66
# Kolkata           61
# Delhi             60
# Hyderabad         49
# Chennai           48
# Chandigarh        46
# Jaipur            33
# Pune              32
# Durban            15
# Ahmedabad         12
# Centurion         12
# Visakhapatnam     11
# Rajkot            10
# Dharamsala         9
# Johannesburg       8
# Cape Town          7
# Abu Dhabi          7
# Ranchi             7
# Port Elizabeth     7
# Cuttack            7
# Raipur             6
# Sharjah            6
# Kochi              5
# Indore             5
# Kanpur             4
# Nagpur             3
# Kimberley          3
# East London        3
# Bloemfontein       2
# Name: count, dtype: int64

# %%
np.sum(ipl['toss_winner'])
# Out:
# 'Royal Challengers BangaloreRising Pune SupergiantKolkata Knight RidersKings XI PunjabRoyal Challengers BangaloreSunrisers HyderabadMumbai IndiansRoyal Challengers BangaloreRising Pune SupergiantMumbai IndiansKolkata Knight RidersMumbai IndiansGujarat LionsSunrisers HyderabadDelhi DaredevilsMumbai IndiansRoyal Challengers BangaloreDelhi DaredevilsKings XI PunjabGujarat LionsSunrisers HyderabadMumbai IndiansGujarat LionsDelhi DaredevilsRising Pune SupergiantGujarat LionsRoyal Challengers BangaloreMumbai IndiansKolkata Knight RidersGujarat LionsKolkata Knight RidersKings XI PunjabRoyal Challengers BangaloreGujarat LionsKings XI PunjabKolkata Knight RidersRoyal Challengers BangaloreRising Pune SupergiantDelhi DaredevilsRising Pune SupergiantDelhi DaredevilsRoyal Challengers BangaloreSunrisers HyderabadDelhi DaredevilsKolkata Knight RidersGujarat LionsMumbai IndiansKolkata Knight RidersDelhi DaredevilsMumbai IndiansDelhi DaredevilsSunrisers HyderabadKolkata Knight RidersRising Pune Super
# ...

# %%
ipl['toss_winner'] == ipl['winner']
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 631     True
# 632     True
# 633    False
# 634     True
# 635     True
# Length: 636, dtype: bool

# %%
np.sum(ipl['toss_winner'] == ipl['winner'])
# Out:
# 325

# %%
(325/636)*100
# Out:
# 51.100628930817614

# %%
deliveries = pd.read_csv('deliveries.csv')
deliveries
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 0         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...          ...     ...                    ...                          ...
# 260915   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260916   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260917   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260918   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260919   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
#
# ...

# %%
deliveries['match_id'].unique()
# Out:
# array([ 335982,  335983,  335984, ..., 1426310, 1426311, 1426312],
#       dtype=int64)

# %%
match_1 = deliveries[deliveries['match_id']==335982]
match_1
# Out:
#      match_id  inning                 batting_team  \
# 0      335982       1        Kolkata Knight Riders
# 1      335982       1        Kolkata Knight Riders
# 2      335982       1        Kolkata Knight Riders
# 3      335982       1        Kolkata Knight Riders
# 4      335982       1        Kolkata Knight Riders
# ..        ...     ...                          ...
# 220    335982       2  Royal Challengers Bangalore
# 221    335982       2  Royal Challengers Bangalore
# 222    335982       2  Royal Challengers Bangalore
# 223    335982       2  Royal Challengers Bangalore
# 224    335982       2  Royal Challengers Bangalore
#
#                     bowling_team  over  ball       batter     bowler  \
# 0    Royal Challengers Bangalore     0     1   SC Ganguly    P Kumar
# 1    Royal Challengers Bangalore     0     2  BB McCullum    P Kumar
# 2    Royal Challengers Bangalore     0     3  BB McCullum    P Kumar
# 3    Royal Challengers Bangalore     0     4  BB McCullum    P Kumar
# ...

# %%
match_1.head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# ...

# %%
match_1.shape
# Out:
# (225, 17)

# %%
kkr= match_1[match_1['inning']==1]

# %%
kkr['batsman_runs'].value_counts()
# Out:
# batsman_runs
# 0    45
# 1    39
# 4    15
# 6    14
# 2    11
# Name: count, dtype: int64

# %%
np.sum(kkr['batsman_runs'].value_counts())
# Out:
# 124

# %%
kkr['player_dismissed'].value_counts()
# Out:
# player_dismissed
# SC Ganguly    1
# RT Ponting    1
# DJ Hussey     1
# Name: count, dtype: int64

# %%
kkr['dismissal_kind'].value_counts()
# Out:
# dismissal_kind
# caught    3
# Name: count, dtype: int64

# %%
kkr['extras_type'].value_counts()
# Out:
# extras_type
# legbyes    4
# wides      4
# byes       1
# Name: count, dtype: int64

# %%
np.sum(kkr['total_runs'].value_counts())
# Out:
# 124

# %%
rcb= match_1[match_1['inning']==2]
rcb
# Out:
#      match_id  inning                 batting_team           bowling_team  \
# 124    335982       2  Royal Challengers Bangalore  Kolkata Knight Riders
# 125    335982       2  Royal Challengers Bangalore  Kolkata Knight Riders
# 126    335982       2  Royal Challengers Bangalore  Kolkata Knight Riders
# 127    335982       2  Royal Challengers Bangalore  Kolkata Knight Riders
# 128    335982       2  Royal Challengers Bangalore  Kolkata Knight Riders
# ..        ...     ...                          ...                    ...
# 220    335982       2  Royal Challengers Bangalore  Kolkata Knight Riders
# 221    335982       2  Royal Challengers Bangalore  Kolkata Knight Riders
# 222    335982       2  Royal Challengers Bangalore  Kolkata Knight Riders
# 223    335982       2  Royal Challengers Bangalore  Kolkata Knight Riders
# 224    335982       2  Royal Challengers Bangalore  Kolkata Knight Riders
#
#      over  ball    batter     bowler non_striker  batsman_runs  extra_runs  \
# ...

# %%
rcb['batsman_runs'].value_counts()
# Out:
# batsman_runs
# 0    65
# 1    27
# 2     3
# 6     3
# 4     3
# Name: count, dtype: int64

# %%
rcb['dismissal_kind'].value_counts()
# Out:
# dismissal_kind
# caught     6
# bowled     3
# run out    1
# Name: count, dtype: int64

# %%
rcb['extras_type'].value_counts()
# Out:
# extras_type
# wides      10
# legbyes     5
# Name: count, dtype: int64

# %%
np.sum(rcb['total_runs'].value_counts())
# Out:
# 101
